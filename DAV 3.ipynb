# %%
import pandas as pd
# Load dataset into a DataFrame
df = pd.read_csv('data.csv')
# Display first and last few rows
print("First 5 rows:\n", df.head())
print("Last 5 rows:\n", df.tail())
# Check data types and general info
df.info()
# Summary statistics
print("Summary statistics:\n", df.describe())
# Handle missing values
df.fillna(df.mean(numeric_only=True), inplace=True)
# Create a new column
df['new_column'] = df['existing_column'] * 2
# Create a Series and perform operations
series = df['existing_column']
print("Series addition:", series + 10)
# Filter rows based on conditions
filtered_df = df[(df['existing_column'] > 50) & (df['another_column'] < 100)]
print("Filtered DataFrame:\n", filtered_df)
# Grouping and aggregation
grouped = df.groupby('category_column')['numeric_column'].mean()
print("Grouped mean:\n", grouped)
# Sorting
df_sorted = df.sort_values(by='numeric_column', ascending=False)
print("Sorted DataFrame:\n", df_sorted)
# Boolean masking
masked_df = df[df['numeric_column'] > df['numeric_column'].median()]

print("Masked DataFrame:\n", masked_df)
# Remove duplicates and drop missing values
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# Create a new DataFrame with selected columns
subset_df = df[['column1', 'column2']]
# Save the new DataFrame to a CSV file
subset_df.to_csv('filtered_data.csv', index=False)
# Compute summary statistics
print("Total sum:", df['numeric_column'].sum())
print("Mean:", df['numeric_column'].mean())
print("Standard Deviation:", df['numeric_column'].std())
# Out:
# First 5 rows:
#    column1  column2  existing_column  another_column category_column  \
# 0       A       10               60              80            Food
# 1       B       20               45             120            Tech
# 2       C       30               75              60            Food
# 3       D       40               20              90          Health
# 4       E       50               90              70            Tech
#
#    numeric_column
# 0             100
# 1             200
# 2             150
# 3             300
# 4             250
# Last 5 rows:
#    column1  column2  existing_column  another_column category_column  \
# 5       F       60               55             110          Health
# 6       G       70               65              95            Food
# 7       H       80               85              85            Tech
# 8       I       90               40             130          Health
# 9       J      100               95              75            Food
#
#    numeric_column
# 5             180
# 6             220
# 7             270
# 8             160
# 9             310
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   column1          10 non-null     str
#  1   column2          10 non-null     int64
#  2   existing_column  10 non-null     int64
#  3   another_column   10 non-null     int64
#  4   category_column  10 non-null     str
#  5   numeric_column   10 non-null     int64
# dtypes: int64(4), str(2)
# memory usage: 612.0 bytes
# Summary statistics:
#            column2  existing_column  another_column  numeric_column
# count   10.000000         10.00000       10.000000       10.000000
# mean    55.000000         63.00000       91.500000      214.000000
# std     30.276504         23.94438       22.490739       68.669903
# min     10.000000         20.00000       60.000000      100.000000
# 25%     32.500000         47.50000       76.250000      165.000000
# 50%     55.000000         62.50000       87.500000      210.000000
# 75%     77.500000         82.50000      106.250000      265.000000
# max    100.000000         95.00000      130.000000      310.000000
# Series addition: 0     70
# 1     55
# 2     85
# 3     30
# 4    100
# 5     65
# 6     75
# 7     95
# 8     50
# 9    105
# Name: existing_column, dtype: int64
# Filtered DataFrame:
#    column1  column2  existing_column  another_column category_column  \
# 0       A       10               60              80            Food
# 2       C       30               75              60            Food
# 4       E       50               90              70            Tech
# 6       G       70               65              95            Food
# 7       H       80               85              85            Tech
# 9       J      100               95              75            Food
#
#    numeric_column  new_column
# 0             100         120
# 2             150         150
# 4             250         180
# 6             220         130
# 7             270         170
# 9             310         190
# Grouped mean:
#  category_column
# Food      195.000000
# Health    213.333333
# Tech      240.000000
# Name: numeric_column, dtype: float64
# Sorted DataFrame:
#    column1  column2  existing_column  another_column category_column  \
# 9       J      100               95              75            Food
# 3       D       40               20              90          Health
# 7       H       80               85              85            Tech
# 4       E       50               90              70            Tech
# 6       G       70               65              95            Food
# 1       B       20               45             120            Tech
# 5       F       60               55             110          Health
# 8       I       90               40             130          Health
# 2       C       30               75              60            Food
# 0       A       10               60              80            Food
#
#    numeric_column  new_column
# 9             310         190
# 3             300          40
# 7             270         170
# 4             250         180
# 6             220         130
# 1             200          90
# 5             180         110
# 8             160          80
# 2             150         150
# 0             100         120
# Masked DataFrame:
#    column1  column2  existing_column  another_column category_column  \
# 3       D       40               20              90          Health
# 4       E       50               90              70            Tech
# 6       G       70               65              95            Food
# 7       H       80               85              85            Tech
# 9       J      100               95              75            Food
#
#    numeric_column  new_column
# 3             300          40
# 4             250         180
# 6             220         130
# 7             270         170
# 9             310         190
# Total sum: 2140
# Mean: 214.0
# Standard Deviation: 68.66990283636315
